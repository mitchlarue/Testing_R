# %%
install.packages("dplyr")
install.packages("tidyr")
install.packages("ggplot2")
install.packages("data.table")
install.packages("tidyverse")
install.packages("viridis")
install.packages("hrbrthemes")
install.packages("zoo")
install.packages("maps")
install.packages("choroplethr")
install.packages("choroplethrMaps")
install.packages("reshape2")
# Out:
# Installing package into 'C:/Users/mitch/OneDrive/Documents/R/win-library/4.1'
# (as 'lib' is unspecified)
# package 'dplyr' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\mitch\AppData\Local\Temp\RtmpiYuvUy\downloaded_packages
# Installing package into 'C:/Users/mitch/OneDrive/Documents/R/win-library/4.1'
# (as 'lib' is unspecified)
#   There is a binary version available but the source version is later:
#       binary source needs_compilation
# tidyr  1.1.4  1.2.0              TRUE
#
#   Binaries will be installed
# package 'tidyr' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\mitch\AppData\Local\Temp\RtmpiYuvUy\downloaded_packages
# Installing package into 'C:/Users/mitch/OneDrive/Documents/R/win-library/4.1'
# (as 'lib' is unspecified)
# package 'ggplot2' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\mitch\AppData\Local\Temp\RtmpiYuvUy\downloaded_packages
# Installing package into 'C:/Users/mitch/OneDrive/Documents/R/win-library/4.1'
# (as 'lib' is unspecified)
# package 'data.table' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\mitch\AppData\Local\Temp\RtmpiYuvUy\downloaded_packages
# Installing package into 'C:/Users/mitch/OneDrive/Documents/R/win-library/4.1'
# (as 'lib' is unspecified)
# package 'tidyverse' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\mitch\AppData\Local\Temp\RtmpiYuvUy\downloaded_packages
# Installing package into 'C:/Users/mitch/OneDrive/Documents/R/win-library/4.1'
# (as 'lib' is unspecified)
# package 'viridis' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\mitch\AppData\Local\Temp\RtmpiYuvUy\downloaded_packages
# Installing package into 'C:/Users/mitch/OneDrive/Documents/R/win-library/4.1'
# (as 'lib' is unspecified)
# package 'hrbrthemes' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\mitch\AppData\Local\Temp\RtmpiYuvUy\downloaded_packages
# Installing package into 'C:/Users/mitch/OneDrive/Documents/R/win-library/4.1'
# (as 'lib' is unspecified)
# package 'zoo' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\mitch\AppData\Local\Temp\RtmpiYuvUy\downloaded_packages
# Installing package into 'C:/Users/mitch/OneDrive/Documents/R/win-library/4.1'
# (as 'lib' is unspecified)
# package 'maps' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\mitch\AppData\Local\Temp\RtmpiYuvUy\downloaded_packages
# Installing package into 'C:/Users/mitch/OneDrive/Documents/R/win-library/4.1'
# (as 'lib' is unspecified)
# package 'choroplethr' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\mitch\AppData\Local\Temp\RtmpiYuvUy\downloaded_packages
# Installing package into 'C:/Users/mitch/OneDrive/Documents/R/win-library/4.1'
# (as 'lib' is unspecified)
# package 'choroplethrMaps' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\mitch\AppData\Local\Temp\RtmpiYuvUy\downloaded_packages
# Installing package into 'C:/Users/mitch/OneDrive/Documents/R/win-library/4.1'
# (as 'lib' is unspecified)
# package 'reshape2' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\mitch\AppData\Local\Temp\RtmpiYuvUy\downloaded_packages

# %%
library(dplyr)
library(tidyr)
library(ggplot2)
library(choroplethr)
library(choroplethrMaps)
library(viridis)
library(hrbrthemes)
library(reshape2)
clim_data = read.csv("D:/Downloads/GlobalLandTemp/GlobalLandTemperaturesByState.csv", header = TRUE)
# Out:
# Attaching package: 'dplyr'
#
#
# The following objects are masked from 'package:stats':
#
#     filter, lag
#
#
# The following objects are masked from 'package:base':
#
#     intersect, setdiff, setequal, union
#
#
# Loading required package: acs
#
# Loading required package: stringr
#
# Loading required package: XML
#
#
# Attaching package: 'acs'
#
#
# The following object is masked from 'package:dplyr':
#
#     combine
#
#
# The following object is masked from 'package:base':
#
#     apply
#
#
# Loading required package: viridisLite
#
# NOTE: Either Arial Narrow or Roboto Condensed fonts are required to use these themes.
#
#       Please use hrbrthemes::import_roboto_condensed() to install Roboto Condensed and
#
#       if Arial Narrow is not on your system, please see https://bit.ly/arialnarrow
#
#
# Attaching package: 'reshape2'
#
#
# The following object is masked from 'package:tidyr':
#
#     smiths

# %%
clim_data %>%
    filter(Country == "United States") %>%
    separate(col = dt, into = c("Year", "Month", "Day"), convert = TRUE) -> clim_data  
clim_data = na.omit(clim_data)

# %%
head(clim_data)
# Out:
#        Year Month Day AverageTemperature AverageTemperatureUncertainty State
# 1      1743 11    1   10.722             2.898                         Alabama
# 6      1744  4    1   19.075             2.902                         Alabama
# 7      1744  5    1   21.197             2.844                         Alabama
# 8      1744  6    1   25.290             2.879                         Alabama
# 9      1744  7    1   26.420             2.841                         Alabama
# 11     1744  9    1   21.735             2.866                         Alabama
# 12     1744 10    1   15.630             2.872                         Alabama
# 13     1744 11    1   11.198             2.806                         Alabama
# 14     1744 12    1    7.063             2.823                         Alabama
# 15     1745  1    1    6.931             2.838                         Alabama
# 16     1745  2    1    8.621             2.750                         Alabama
# 17     1745  3    1   11.232             2.757                         Alabama
# 18     1745  4    1   16.799             2.749                         Alabama
# 75     1750  1    1    7.444             2.724                         Alabama
# 76     1750  2    1    9.311             2.956                         Alabama
# 77     1750  3    1   13.229             3.127                         Alabama
# 78     1750  4    1   17.303             2.761                         Alabama
# 79     1750  5    1   21.966             2.823                         Alabama
# 80     1750  6    1   24.568             2.800                         Alabama
# 81     1750  7    1   28.464             2.787                         Alabama
# 82     1750  8    1   27.126             2.734                         Alabama
# 83     1750  9    1   22.742             2.773                         Alabama
# 84     1750 10    1   15.084             2.778                         Alabama
#   Year Month Day AverageTemperature AverageTemperatureUncertainty State
# 1 1743 11    1   10.722             2.898                         Alabama
# 2 1744  4    1   19.075             2.902                         Alabama
# 3 1744  5    1   21.197             2.844                         Alabama
# 4 1744  6    1   25.290             2.879                         Alabama
# 5 1744  7    1   26.420             2.841                         Alabama
# 6 1744  9    1   21.735             2.866                         Alabama
#   Country
# 1 United States
# 2 United States
# 3 United States
# 4 United States
# 5 United States
# 6 United States

# %%
clim_data1 %>%
filter(Year>1900) %>%
group_by(Year) %>%
summarise(Temp = mean(AverageTemperature)) -> clim_data2
head(clim_data2)
# Out:
#   Year Temp
# 1 1901 10.62789
# 2 1902 10.66416
# 3 1903 10.26386
# 4 1904 10.03563
# 5 1905 10.32431
# 6 1906 10.86005

# %%
qplot(Year, Temp, data=clim_data2, main="Average Temperature 1900-2013", geom=c("point","smooth")) + aes(color = Temp) + scale_color_gradient(low="grey", high="red")
# Out:
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# plot without title

# %%
clim_data$State <- as.character(clim_data$State)
clim_data$State[clim_data$State=="Georgia (State)"] <- "Georgia"
clim_data$State<- as.factor(clim_data$State)

# %%
clim_data %>%
select(Year, AverageTemperature, State) %>%
group_by(Year,State) %>%
summarize(value = mean(AverageTemperature), .groups = 'drop') -> clim_data3

colnames(clim_data3)[2] <- "region" 
clim_data3$region<-tolower(clim_data3$region)

clim_data3 %>%
filter(Year==1900) -> clim_data1900
clim_data1900<-clim_data1900[,2:3]

# %%
clim_data1900
# Out:
#    region               value
# 1  alabama              17.059167
# 2  alaska               -5.146500
# 3  arizona              15.742917
# 4  arkansas             15.893417
# 5  california           14.515750
# 6  colorado              7.470917
# 7  connecticut           9.763167
# 8  delaware             12.690167
# 9  district of columbia 12.712083
# 10 florida              21.344750
# 11 georgia              17.492667
# 12 hawaii               22.429250
# 13 idaho                 6.275917
# 14 illinois             11.423833
# 15 indiana              11.446667
# 16 iowa                  9.322500
# 17 kansas               12.764667
# 18 kentucky             13.414750
# 19 louisiana            19.020583
# 20 maine                 4.675333
# 21 maryland             12.896167
# 22 massachusetts         8.245833
# 23 michigan              7.180833
# 24 minnesota             5.405583
# 25 mississippi          17.587417
# 26 missouri             12.810083
# 27 montana               6.094750
# 28 nebraska             10.057500
# 29 nevada               10.332917
# 30 new hampshire         6.001583
# 31 new jersey           11.463833
# 32 new mexico           12.172417
# 33 new york              7.859583
# 34 north carolina       15.137750
# 35 north dakota          5.195500
# 36 ohio                 10.906667
# 37 oklahoma             15.558417
# 38 oregon                8.671583
# 39 pennsylvania          9.888417
# 40 rhode island          9.702167
# 41 south carolina       17.147167
# 42 south dakota          8.186000
# 43 tennessee            14.341667
# 44 texas                17.984167
# 45 utah                  9.206917
# 46 vermont               5.781917
# 47 virginia             13.428917
# 48 washington            8.185667
# 49 west virginia        11.528750
# 50 wisconsin             6.624167
# 51 wyoming               6.130667

# %%
print(state_choropleth(clim_data1900,
                       title="Land Temperature 1900", 
                       num_colors = 8,
                       legend="Degrees"),reference_map=TRUE)
# Out:
# plot without title

# %%
clim_data3 %>%
filter(Year==2000) -> clim_data2000
clim_data2000<-clim_data2000[,2:3]

# %%
print(state_choropleth(clim_data2000,
                       title="Land Temperature 2000", 
                       num_colors = 8,
                       legend="Degrees"),reference_map=TRUE)
# Out:
# plot without title

# %%
ggplot(clim_data3, aes(x=Year, y=value, color=as.factor(region))) +
geom_point(size=3) +
facet_wrap(∼region) +
theme(legend.position="none")
# Out:
# plot without title

# %%
clim_data3 %>%
    filter(region == "washington") -> wa_clim
wa_clim <- na.omit(wa_clim)

# %%
wa_clim
# Out:
#     Year region     value
# 1   1828 washington 7.235727
# 2   1829 washington 6.834182
# 3   1832 washington 2.855625
# 4   1833 washington 7.645417
# 5   1834 washington 7.274417
# 6   1835 washington 5.542091
# 7   1836 washington 6.849917
# 8   1837 washington 6.934750
# 9   1838 washington 6.698250
# 10  1839 washington 7.464000
# 11  1840 washington 6.829417
# 12  1841 washington 6.951333
# 13  1842 washington 7.058667
# 14  1843 washington 6.660417
# 15  1844 washington 6.531750
# 16  1845 washington 7.046000
# 17  1847 washington 9.620375
# 18  1848 washington 6.723917
# 19  1849 washington 6.813583
# 20  1850 washington 7.209583
# 21  1851 washington 7.920500
# 22  1852 washington 7.207500
# 23  1853 washington 7.736083
# 24  1854 washington 7.169167
# 25  1855 washington 7.436583
# 26  1856 washington 7.574167
# 27  1857 washington 8.054417
# 28  1858 washington 7.068667
# 29  1859 washington 6.380583
# 30  1860 washington 7.778917
# ... ...  ...        ...
# 154 1984 washington  7.356750
# 155 1985 washington  6.574917
# 156 1986 washington  8.401333
# 157 1987 washington  8.887917
# 158 1988 washington  8.402917
# 159 1989 washington  7.971750
# 160 1990 washington  8.371167
# 161 1991 washington  8.302250
# 162 1992 washington  9.152750
# 163 1993 washington  7.423583
# 164 1994 washington  8.724583
# 165 1995 washington  8.561167
# 166 1996 washington  7.507667
# 167 1997 washington  8.368667
# 168 1998 washington  9.123000
# 169 1999 washington  8.242667
# 170 2000 washington  7.859917
# 171 2001 washington  8.284000
# 172 2002 washington  8.288750
# 173 2003 washington  9.032333
# 174 2004 washington  9.111833
# 175 2005 washington  8.531750
# 176 2006 washington  8.675333
# 177 2007 washington  8.302417
# 178 2008 washington  7.685917
# 179 2009 washington  8.047583
# 180 2010 washington  8.442167
# 181 2011 washington  7.619333
# 182 2012 washington  8.477917
# 183 2013 washington 10.571778

# %%
ggplot(wa_clim, aes(x=Year, y=value, color=as.factor(region))) +
geom_point(size=3) +
facet_wrap(∼region) +
theme(legend.position="none")
# Out:
# plot without title

# %%
clim_data3 %>%
    filter(region == "oregon") -> or_clim
or_clim <- na.omit(or_clim)

# %%
or_clim
# Out:
#     Year region value
# 1   1828 oregon  7.843182
# 2   1829 oregon  7.360727
# 3   1832 oregon  3.466000
# 4   1833 oregon  8.095917
# 5   1834 oregon  7.843833
# 6   1835 oregon  6.067727
# 7   1836 oregon  7.335083
# 8   1837 oregon  7.383167
# 9   1838 oregon  7.199333
# 10  1839 oregon  7.826250
# 11  1840 oregon  7.357917
# 12  1841 oregon  7.430750
# 13  1842 oregon  7.583167
# 14  1843 oregon  7.337333
# 15  1844 oregon  7.123250
# 16  1845 oregon  7.591500
# 17  1847 oregon 10.098625
# 18  1848 oregon  7.309333
# 19  1849 oregon  7.538333
# 20  1850 oregon  7.714333
# 21  1851 oregon  8.372000
# 22  1852 oregon  7.638750
# 23  1853 oregon  8.370250
# 24  1854 oregon  7.709500
# 25  1855 oregon  8.015667
# 26  1856 oregon  8.021750
# 27  1857 oregon  8.568167
# 28  1858 oregon  7.769583
# 29  1859 oregon  7.064750
# 30  1860 oregon  8.062000
# ... ...  ...    ...
# 154 1984 oregon  7.715833
# 155 1985 oregon  7.136250
# 156 1986 oregon  9.047667
# 157 1987 oregon  9.132833
# 158 1988 oregon  8.908750
# 159 1989 oregon  8.187167
# 160 1990 oregon  8.605333
# 161 1991 oregon  8.716000
# 162 1992 oregon  9.712500
# 163 1993 oregon  7.580667
# 164 1994 oregon  8.877417
# 165 1995 oregon  9.010500
# 166 1996 oregon  8.723000
# 167 1997 oregon  8.838833
# 168 1998 oregon  8.897083
# 169 1999 oregon  8.541000
# 170 2000 oregon  8.678000
# 171 2001 oregon  8.882667
# 172 2002 oregon  8.806167
# 173 2003 oregon  9.564250
# 174 2004 oregon  9.285167
# 175 2005 oregon  8.840000
# 176 2006 oregon  8.960333
# 177 2007 oregon  8.895833
# 178 2008 oregon  8.315167
# 179 2009 oregon  8.559083
# 180 2010 oregon  8.574583
# 181 2011 oregon  8.077583
# 182 2012 oregon  9.030083
# 183 2013 oregon 10.763556

# %%
ggplot(or_clim, aes(x=Year, y=value, color=as.factor(region))) +
geom_point(size=3) +
facet_wrap(∼region) +
theme(legend.position="none")
# Out:
# plot without title

# %%
com_clim <- merge(wa_clim, or_clim, by = 'Year')

# %%
com_clim
# Out:
#     Year region.x   value.x   region.y value.y
# 1   1828 washington 7.235727  oregon    7.843182
# 2   1829 washington 6.834182  oregon    7.360727
# 3   1832 washington 2.855625  oregon    3.466000
# 4   1833 washington 7.645417  oregon    8.095917
# 5   1834 washington 7.274417  oregon    7.843833
# 6   1835 washington 5.542091  oregon    6.067727
# 7   1836 washington 6.849917  oregon    7.335083
# 8   1837 washington 6.934750  oregon    7.383167
# 9   1838 washington 6.698250  oregon    7.199333
# 10  1839 washington 7.464000  oregon    7.826250
# 11  1840 washington 6.829417  oregon    7.357917
# 12  1841 washington 6.951333  oregon    7.430750
# 13  1842 washington 7.058667  oregon    7.583167
# 14  1843 washington 6.660417  oregon    7.337333
# 15  1844 washington 6.531750  oregon    7.123250
# 16  1845 washington 7.046000  oregon    7.591500
# 17  1847 washington 9.620375  oregon   10.098625
# 18  1848 washington 6.723917  oregon    7.309333
# 19  1849 washington 6.813583  oregon    7.538333
# 20  1850 washington 7.209583  oregon    7.714333
# 21  1851 washington 7.920500  oregon    8.372000
# 22  1852 washington 7.207500  oregon    7.638750
# 23  1853 washington 7.736083  oregon    8.370250
# 24  1854 washington 7.169167  oregon    7.709500
# 25  1855 washington 7.436583  oregon    8.015667
# 26  1856 washington 7.574167  oregon    8.021750
# 27  1857 washington 8.054417  oregon    8.568167
# 28  1858 washington 7.068667  oregon    7.769583
# 154 1984 washington  7.356750 oregon    7.715833  0.3590833
# 155 1985 washington  6.574917 oregon    7.136250  0.5613333
# 156 1986 washington  8.401333 oregon    9.047667  0.6463333
# 157 1987 washington  8.887917 oregon    9.132833  0.2449167
# 158 1988 washington  8.402917 oregon    8.908750  0.5058333
# 159 1989 washington  7.971750 oregon    8.187167  0.2154167
# 160 1990 washington  8.371167 oregon    8.605333  0.2341667
# 161 1991 washington  8.302250 oregon    8.716000  0.4137500
# 162 1992 washington  9.152750 oregon    9.712500  0.5597500
# 163 1993 washington  7.423583 oregon    7.580667  0.1570833
# 164 1994 washington  8.724583 oregon    8.877417  0.1528333
# 165 1995 washington  8.561167 oregon    9.010500  0.4493333
# 166 1996 washington  7.507667 oregon    8.723000  1.2153333
# 167 1997 washington  8.368667 oregon    8.838833  0.4701667
# 168 1998 washington  9.123000 oregon    8.897083 -0.2259167
# 169 1999 washington  8.242667 oregon    8.541000  0.2983333
# 170 2000 washington  7.859917 oregon    8.678000  0.8180833
# 171 2001 washington  8.284000 oregon    8.882667  0.5986667
# 172 2002 washington  8.288750 oregon    8.806167  0.5174167
# 173 2003 washington  9.032333 oregon    9.564250  0.5319167
# 174 2004 washington  9.111833 oregon    9.285167  0.1733333
# 175 2005 washington  8.531750 oregon    8.840000  0.3082500
# 176 2006 washington  8.675333 oregon    8.960333  0.2850000
# 177 2007 washington  8.302417 oregon    8.895833  0.5934167
# 178 2008 washington  7.685917 oregon    8.315167  0.6292500
# 179 2009 washington  8.047583 oregon    8.559083  0.5115000
# 180 2010 washington  8.442167 oregon    8.574583  0.1324167
# 181 2011 washington  7.619333 oregon    8.077583  0.4582500
# 182 2012 washington  8.477917 oregon    9.030083  0.5521667
# 183 2013 washington 10.571778 oregon   10.763556  0.1917778

# %%
ggplot(com_clim, aes(x=Year, y=TempDiff, color = "red", group = 1)) +
stat_boxplot()
# Out:
# plot without title

# %%
ggplot(com_clim, aes(x=Year, y=TempDiff)) +
geom_bin_2d()
# Out:
# plot without title

# %%
com_clim %>%
rename(WA = region.x ,
       WA_temperature = value.x,
      OR = region.y ,
      OR_temperature = value.y,
      ) -> com_clim

# %%
com_clim
# Out:
#     Year WA         WA_temperature OR     OR_temperature TempDiff
# 1   1828 washington 7.235727       oregon  7.843182      0.6074545
# 2   1829 washington 6.834182       oregon  7.360727      0.5265455
# 3   1832 washington 2.855625       oregon  3.466000      0.6103750
# 4   1833 washington 7.645417       oregon  8.095917      0.4505000
# 5   1834 washington 7.274417       oregon  7.843833      0.5694167
# 6   1835 washington 5.542091       oregon  6.067727      0.5256364
# 7   1836 washington 6.849917       oregon  7.335083      0.4851667
# 8   1837 washington 6.934750       oregon  7.383167      0.4484167
# 9   1838 washington 6.698250       oregon  7.199333      0.5010833
# 10  1839 washington 7.464000       oregon  7.826250      0.3622500
# 11  1840 washington 6.829417       oregon  7.357917      0.5285000
# 12  1841 washington 6.951333       oregon  7.430750      0.4794167
# 13  1842 washington 7.058667       oregon  7.583167      0.5245000
# 14  1843 washington 6.660417       oregon  7.337333      0.6769167
# 15  1844 washington 6.531750       oregon  7.123250      0.5915000
# 16  1845 washington 7.046000       oregon  7.591500      0.5455000
# 17  1847 washington 9.620375       oregon 10.098625      0.4782500
# 18  1848 washington 6.723917       oregon  7.309333      0.5854167
# 19  1849 washington 6.813583       oregon  7.538333      0.7247500
# 20  1850 washington 7.209583       oregon  7.714333      0.5047500
# 21  1851 washington 7.920500       oregon  8.372000      0.4515000
# 22  1852 washington 7.207500       oregon  7.638750      0.4312500
# 23  1853 washington 7.736083       oregon  8.370250      0.6341667
# 24  1854 washington 7.169167       oregon  7.709500      0.5403333
# 25  1855 washington 7.436583       oregon  8.015667      0.5790833
# 26  1856 washington 7.574167       oregon  8.021750      0.4475833
# 27  1857 washington 8.054417       oregon  8.568167      0.5137500
# 28  1858 washington 7.068667       oregon  7.769583      0.7009167
# 29  1859 washington 6.380583       oregon  7.064750      0.6841667
# 30  1860 washington 7.778917       oregon  8.062000      0.2830833
# ... ...  ...        ...            ...    ...            ...
# 154 1984 washington  7.356750      oregon  7.715833       0.3590833
# 155 1985 washington  6.574917      oregon  7.136250       0.5613333
# 156 1986 washington  8.401333      oregon  9.047667       0.6463333
# 157 1987 washington  8.887917      oregon  9.132833       0.2449167
# 158 1988 washington  8.402917      oregon  8.908750       0.5058333
# 159 1989 washington  7.971750      oregon  8.187167       0.2154167
# 160 1990 washington  8.371167      oregon  8.605333       0.2341667
# 161 1991 washington  8.302250      oregon  8.716000       0.4137500
# 162 1992 washington  9.152750      oregon  9.712500       0.5597500
# 163 1993 washington  7.423583      oregon  7.580667       0.1570833
# 164 1994 washington  8.724583      oregon  8.877417       0.1528333
# 165 1995 washington  8.561167      oregon  9.010500       0.4493333
# 166 1996 washington  7.507667      oregon  8.723000       1.2153333
# 167 1997 washington  8.368667      oregon  8.838833       0.4701667
# 168 1998 washington  9.123000      oregon  8.897083      -0.2259167
# 169 1999 washington  8.242667      oregon  8.541000       0.2983333
# 170 2000 washington  7.859917      oregon  8.678000       0.8180833
# 171 2001 washington  8.284000      oregon  8.882667       0.5986667
# 172 2002 washington  8.288750      oregon  8.806167       0.5174167
# 173 2003 washington  9.032333      oregon  9.564250       0.5319167
# 174 2004 washington  9.111833      oregon  9.285167       0.1733333
# 175 2005 washington  8.531750      oregon  8.840000       0.3082500
# 176 2006 washington  8.675333      oregon  8.960333       0.2850000
# 177 2007 washington  8.302417      oregon  8.895833       0.5934167
# 178 2008 washington  7.685917      oregon  8.315167       0.6292500
# 179 2009 washington  8.047583      oregon  8.559083       0.5115000
# 180 2010 washington  8.442167      oregon  8.574583       0.1324167
# 181 2011 washington  7.619333      oregon  8.077583       0.4582500
# 182 2012 washington  8.477917      oregon  9.030083       0.5521667
# 183 2013 washington 10.571778      oregon 10.763556       0.1917778

# %%
com_clim1 <- subset(com_clim, select = -TempDiff)

# %%
com_clim1
# Out:
#     Year WA         WA_temperature OR     OR_temperature
# 1   1828 washington 7.235727       oregon  7.843182
# 2   1829 washington 6.834182       oregon  7.360727
# 3   1832 washington 2.855625       oregon  3.466000
# 4   1833 washington 7.645417       oregon  8.095917
# 5   1834 washington 7.274417       oregon  7.843833
# 6   1835 washington 5.542091       oregon  6.067727
# 7   1836 washington 6.849917       oregon  7.335083
# 8   1837 washington 6.934750       oregon  7.383167
# 9   1838 washington 6.698250       oregon  7.199333
# 10  1839 washington 7.464000       oregon  7.826250
# 11  1840 washington 6.829417       oregon  7.357917
# 12  1841 washington 6.951333       oregon  7.430750
# 13  1842 washington 7.058667       oregon  7.583167
# 14  1843 washington 6.660417       oregon  7.337333
# 15  1844 washington 6.531750       oregon  7.123250
# 16  1845 washington 7.046000       oregon  7.591500
# 17  1847 washington 9.620375       oregon 10.098625
# 18  1848 washington 6.723917       oregon  7.309333
# 19  1849 washington 6.813583       oregon  7.538333
# 20  1850 washington 7.209583       oregon  7.714333
# 21  1851 washington 7.920500       oregon  8.372000
# 22  1852 washington 7.207500       oregon  7.638750
# 23  1853 washington 7.736083       oregon  8.370250
# 24  1854 washington 7.169167       oregon  7.709500
# 25  1855 washington 7.436583       oregon  8.015667
# 26  1856 washington 7.574167       oregon  8.021750
# 27  1857 washington 8.054417       oregon  8.568167
# 28  1858 washington 7.068667       oregon  7.769583
# 29  1859 washington 6.380583       oregon  7.064750
# 30  1860 washington 7.778917       oregon  8.062000
# ... ...  ...        ...            ...    ...
# 154 1984 washington  7.356750      oregon  7.715833
# 155 1985 washington  6.574917      oregon  7.136250
# 156 1986 washington  8.401333      oregon  9.047667
# 157 1987 washington  8.887917      oregon  9.132833
# 158 1988 washington  8.402917      oregon  8.908750
# 159 1989 washington  7.971750      oregon  8.187167
# 160 1990 washington  8.371167      oregon  8.605333
# 161 1991 washington  8.302250      oregon  8.716000
# 162 1992 washington  9.152750      oregon  9.712500
# 163 1993 washington  7.423583      oregon  7.580667
# 164 1994 washington  8.724583      oregon  8.877417
# 165 1995 washington  8.561167      oregon  9.010500
# 166 1996 washington  7.507667      oregon  8.723000
# 167 1997 washington  8.368667      oregon  8.838833
# 168 1998 washington  9.123000      oregon  8.897083
# 169 1999 washington  8.242667      oregon  8.541000
# 170 2000 washington  7.859917      oregon  8.678000
# 171 2001 washington  8.284000      oregon  8.882667
# 172 2002 washington  8.288750      oregon  8.806167
# 173 2003 washington  9.032333      oregon  9.564250
# 174 2004 washington  9.111833      oregon  9.285167
# 175 2005 washington  8.531750      oregon  8.840000
# 176 2006 washington  8.675333      oregon  8.960333
# 177 2007 washington  8.302417      oregon  8.895833
# 178 2008 washington  7.685917      oregon  8.315167
# 179 2009 washington  8.047583      oregon  8.559083
# 180 2010 washington  8.442167      oregon  8.574583
# 181 2011 washington  7.619333      oregon  8.077583
# 182 2012 washington  8.477917      oregon  9.030083
# 183 2013 washington 10.571778      oregon 10.763556

# %%
ggplot(com_clim1, aes(x=Year, y=WA_temperature, color = "red")) + 
geom_smooth()
# Out:
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# plot without title

# %%
g <- ggplot(com_clim1, aes(x=Year))
g <- g + geom_smooth(aes(y=WA_temperature, color = "red"))
g <- g + geom_smooth(aes(y=OR_temperature)) + 
ggtitle("Plot of WA and OR Temperature") +
xlab("Year") + ylab("WA Temperature and OR Temperature, WA is red")

# %%
g
# Out:
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
#
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# plot without title

# %%
mdf <- melt(com_clim1, id = c("Year", "WA", "OR"))
mdf
# Out:
#     Year WA         OR     variable       value
# 1   1828 washington oregon WA_temperature 7.235727
# 2   1829 washington oregon WA_temperature 6.834182
# 3   1832 washington oregon WA_temperature 2.855625
# 4   1833 washington oregon WA_temperature 7.645417
# 5   1834 washington oregon WA_temperature 7.274417
# 6   1835 washington oregon WA_temperature 5.542091
# 7   1836 washington oregon WA_temperature 6.849917
# 8   1837 washington oregon WA_temperature 6.934750
# 9   1838 washington oregon WA_temperature 6.698250
# 10  1839 washington oregon WA_temperature 7.464000
# 11  1840 washington oregon WA_temperature 6.829417
# 12  1841 washington oregon WA_temperature 6.951333
# 13  1842 washington oregon WA_temperature 7.058667
# 14  1843 washington oregon WA_temperature 6.660417
# 15  1844 washington oregon WA_temperature 6.531750
# 16  1845 washington oregon WA_temperature 7.046000
# 17  1847 washington oregon WA_temperature 9.620375
# 18  1848 washington oregon WA_temperature 6.723917
# 19  1849 washington oregon WA_temperature 6.813583
# 20  1850 washington oregon WA_temperature 7.209583
# 21  1851 washington oregon WA_temperature 7.920500
# 22  1852 washington oregon WA_temperature 7.207500
# 23  1853 washington oregon WA_temperature 7.736083
# 24  1854 washington oregon WA_temperature 7.169167
# 25  1855 washington oregon WA_temperature 7.436583
# 26  1856 washington oregon WA_temperature 7.574167
# 27  1857 washington oregon WA_temperature 8.054417
# 28  1858 washington oregon WA_temperature 7.068667
# 29  1859 washington oregon WA_temperature 6.380583
# 30  1860 washington oregon WA_temperature 7.778917
# ... ...  ...        ...    ...            ...
# 337 1984 washington oregon OR_temperature  7.715833
# 338 1985 washington oregon OR_temperature  7.136250
# 339 1986 washington oregon OR_temperature  9.047667
# 340 1987 washington oregon OR_temperature  9.132833
# 341 1988 washington oregon OR_temperature  8.908750
# 342 1989 washington oregon OR_temperature  8.187167
# 343 1990 washington oregon OR_temperature  8.605333
# 344 1991 washington oregon OR_temperature  8.716000
# 345 1992 washington oregon OR_temperature  9.712500
# 346 1993 washington oregon OR_temperature  7.580667
# 347 1994 washington oregon OR_temperature  8.877417
# 348 1995 washington oregon OR_temperature  9.010500
# 349 1996 washington oregon OR_temperature  8.723000
# 350 1997 washington oregon OR_temperature  8.838833
# 351 1998 washington oregon OR_temperature  8.897083
# 352 1999 washington oregon OR_temperature  8.541000
# 353 2000 washington oregon OR_temperature  8.678000
# 354 2001 washington oregon OR_temperature  8.882667
# 355 2002 washington oregon OR_temperature  8.806167
# 356 2003 washington oregon OR_temperature  9.564250
# 357 2004 washington oregon OR_temperature  9.285167
# 358 2005 washington oregon OR_temperature  8.840000
# 359 2006 washington oregon OR_temperature  8.960333
# 360 2007 washington oregon OR_temperature  8.895833
# 361 2008 washington oregon OR_temperature  8.315167
# 362 2009 washington oregon OR_temperature  8.559083
# 363 2010 washington oregon OR_temperature  8.574583
# 364 2011 washington oregon OR_temperature  8.077583
# 365 2012 washington oregon OR_temperature  9.030083
# 366 2013 washington oregon OR_temperature 10.763556

# %%
ggplot(mdf)+
geom_smooth(aes(x=Year, y=value, col=variable))
# Out:
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# plot without title
